# %%
# !pip install rasterio
# !pip install --upgrade pandas
# Out:
# Requirement already satisfied: rasterio in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (1.2.10)
# Requirement already satisfied: certifi in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (2020.4.5.1)
# Requirement already satisfied: setuptools in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (46.4.0.post20200518)
# Requirement already satisfied: click>=4.0 in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (7.1.2)
# Requirement already satisfied: click-plugins in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: snuggs>=1.4.1 in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (1.4.7)
# Requirement already satisfied: cligj>=0.5 in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (1.21.5)
# Requirement already satisfied: attrs in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (19.3.0)
# Requirement already satisfied: affine in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from rasterio) (2.3.1)
# Requirement already satisfied: pyparsing>=2.1.6 in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from snuggs>=1.4.1->rasterio) (2.4.7)
# /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages/cryptography/hazmat/backends/openssl/x509.py:18: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   utils.DeprecatedIn35,
# /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages/cryptography/hazmat/backends/openssl/x509.py:18: CryptographyDeprecationWarning: This version of cryptography contains a temporary pyOpenSSL fallback path. Upgrade pyOpenSSL now.
#   utils.DeprecatedIn35,
# Requirement already up-to-date: pandas in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (1.3.5)
# Requirement already satisfied, skipping upgrade: pytz>=2017.3 in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2020.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from pandas) (1.21.5)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from pandas) (2.8.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /Users/ethanhsiao/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.14.0)

# %%
import rasterio
import geopandas as gpd
from pathlib import Path
import asf_search as asf
from shapely.geometry import shape
import matplotlib.pyplot as plt
import pandas as pd

# %%
def transform_data(file):
    place_aoi = gpd.read_file(file)
    place_aoi.geometry.plot()
    place_wkt = place_aoi.geometry.to_wkt()[0]
    opts = {
        'platform': 'S1',#'asf.PLATFORM.SENTINEL1',
        'start': '2019-01-01',
        'end': '2020-02-01',
        'maxResults': 500
        #'processingLevel': asf_search.PRODUCT_TYPE.RTC_HIGH_RES, processingLevel=asf.PRODUCT_TYPE.METADATA,
        #'polarization': asf_search.POLARIZATION.HH_HV,
        #'flightDirection': asf_search.FLIGHT_DIRECTION.ASCENDING
    }
    results = asf.geo_search(intersectsWith=place_wkt, **opts)
    S1A, S1B, ascend_ID, descend_ID, latitude, longitude, metadata, raw, grd_hd = [], [], [], [], [], [], [], [], []
    split_platform(S1A, S1B)
    split_flightDirection(ascend_ID, descend_ID)
    add_latitudeLongitude(latitude, longitude)
    plot_latitudeLongitude(ascend_ID, descend_ID, latitude, longitude)
    split_processingLevel(metadata, raw, grd_hd)
    
    #turn data into df
    df = pd.DataFrame(
    {
        'platform':[],
        'flightDirection':[],
        'centerLat':[],
        'centerLon':[],
        'processingLevel':[]
    })
    platformlist, flightlist, latlist, lonlist, processlist = [], [], [], [], []
    for i in range(len(results)):
        platformlist.append(results[i].properties['platform'])
        flightlist.append(results[i].properties['flightDirection'])
        latlist.append(results[i].properties['centerLat'])
        lonlist.append(results[i].properties['centerLon'])
        processlist.append(results[i].properties['processingLevel'])
    df.platform = platformlist
    df.flightDirection = flightlist
    df.centerLat = latlist
    df.centerLon = lonlist
    df.processingLevel = processlist

    #transform df into gdf
    gdf = gpd.GeoDataFrame(df, 
                           geometry=gpd.points_from_xy(df.centerLon, df.centerLat))
    gdf.head()
    
    world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
    ax = world.plot(color='white', edgecolor='black')
    gdf.plot(ax=ax, color='red')
    plt.show()
    
    #save df
    df.to_csv('data/berkeley.csv', index=False)
    gdf.to_file("data/berkeley.geojson", driver='GeoJSON')
    print('saved files')

# %%
#splitting by platform S1A/S1B
def split_platform(S1A, S1B):
    for i in range(len(results)):
        #print(results[i].properties['platform'])
        if 'Sentinel-1A' in results[i].properties['platform']:
            S1A.append(i)
        elif 'Sentinel-1B' in results[i].properties['platform']:
            S1B.append(i)

# %%
#splitting by ascending/descending flight direction  
def split_flightDirection(ascend_ID, descend_ID):
    for i in range(len(results)):
        if 'ASCENDING' in results[i].properties['flightDirection']:
            ascend_ID.append(i)
        elif 'DESCENDING' in results[i].properties['flightDirection']:
            descend_ID.append(i)

# %%
#add latitude/longitude
def add_latitudeLongitude(latitude, longitude):
    for i in range(len(results)):
        if results[i].properties['centerLat']:
            latitude.append(float(results[i].properties['centerLat']))
        if results[i].properties['centerLat']:
            longitude.append(float(results[i].properties['centerLon']))

# %%
def plot_latitudeLongitude(ascend_ID, descend_ID, latitude, longitude):
    plt.figure('Observations')
    plt.clf()
    for i in range(len(results)):
        if i in ascend_ID:
            plt.scatter(longitude[i],latitude[i],c='red')
        elif i in descend_ID:
            plt.scatter(longitude[i],latitude[i],c='blue')
    plt.xlabel('Longitude')
    plt.ylabel('Latitude')
    plt.title('Top 100 Sentinel 1 Observations')

# %%
#splitting by processingLevel
def split_processingLevel(metadata, raw, grd_hd):
    for i in range(len(results)):
        if 'METADATA_RAW' in results[i].properties['processingLevel']:
            metadata.append(i)
        elif 'GRD_HD' in results[i].properties['processingLevel']:
            grd_hd.append(i)
        else:
            raw.append(i)

# %%
file = 'data/shape.shp'
transform_data(file)
# Out:
# saved files

# %%
results = asf.search(platform=asf.PLATFORM.SENTINEL1, maxResults=100)

# %%
S1A, S1B, ascend_ID, descend_ID, latitude, longitude, metadata, raw, grd_hd = [], [], [], [], [], [], [], [], []
split_platform(S1A, S1B)
split_flightDirection(ascend_ID, descend_ID)
add_latitudeLongitude(latitude, longitude)
plot_latitudeLongitude(ascend_ID, descend_ID, latitude, longitude)
split_processingLevel(metadata, raw, grd_hd)

# %%
df = pd.DataFrame(
{
    'platform':[],
    'flightDirection':[],
    'centerLat':[],
    'centerLon':[],
    'processingLevel':[]
})
platformlist = []
flightlist = []
latlist = []
lonlist = []
processlist = []
for i in range(len(results)):
    platformlist.append(results[i].properties['platform'])
    flightlist.append(results[i].properties['flightDirection'])
    latlist.append(results[i].properties['centerLat'])
    lonlist.append(results[i].properties['centerLon'])
    processlist.append(results[i].properties['processingLevel'])
    
df.platform = platformlist
df.flightDirection = flightlist
df.centerLat = latlist
df.centerLon = lonlist
df.processingLevel = processlist

# %%
df.head()
# Out:
#       platform flightDirection centerLat centerLon processingLevel
# 0  Sentinel-1A       ASCENDING    68.382    3.1993    METADATA_OCN
# 1  Sentinel-1A       ASCENDING    68.382    3.1993             OCN
# 2  Sentinel-1A       ASCENDING   68.1557    3.2603    METADATA_RAW
# 3  Sentinel-1A       ASCENDING   68.1557    3.2603             RAW
# 4  Sentinel-1A       ASCENDING   67.1443    3.8424    METADATA_RAW

# %%
gdf = gpd.GeoDataFrame(
df, geometry=gpd.points_from_xy(df.centerLon, df.centerLat))

# %%
gdf
# Out:
#        platform flightDirection centerLat  centerLon processingLevel  \
# 0   Sentinel-1A       ASCENDING    68.382     3.1993    METADATA_OCN
# 1   Sentinel-1A       ASCENDING    68.382     3.1993             OCN
# 2   Sentinel-1A       ASCENDING   68.1557     3.2603    METADATA_RAW
# 3   Sentinel-1A       ASCENDING   68.1557     3.2603             RAW
# 4   Sentinel-1A       ASCENDING   67.1443     3.8424    METADATA_RAW
# ..          ...             ...       ...        ...             ...
# 95  Sentinel-1A      DESCENDING   64.7043  -139.5253             RAW
# 96  Sentinel-1A      DESCENDING   66.1923  -138.7874    METADATA_RAW
# 97  Sentinel-1A      DESCENDING   66.1923  -138.7874             RAW
# 98  Sentinel-1A      DESCENDING   66.3168  -138.9062          GRD_HD
# 99  Sentinel-1A      DESCENDING   67.6776  -137.9781    METADATA_RAW
#
#                        geometry
# 0      POINT (3.19930 68.38200)
# 1      POINT (3.19930 68.38200)
# 2      POINT (3.26030 68.15570)
# 3      POINT (3.26030 68.15570)
# 4      POINT (3.84240 67.14430)
# ..                          ...
# 95  POINT (-139.52530 64.70430)
# 96  POINT (-138.78740 66.19230)
# 97  POINT (-138.78740 66.19230)
# 98  POINT (-138.90620 66.31680)
# 99  POINT (-137.97810 67.67760)
#
# [100 rows x 6 columns]

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
ax = world.plot(color='white', edgecolor='black')
gdf.plot(ax=ax, color='red')
plt.show()

# %%
#save df
df.to_csv('data/processed.csv', index=False)

# %%
gdf.to_file("data/processed.geojson", driver='GeoJSON')
#gdf.to_file("countries.shp")
